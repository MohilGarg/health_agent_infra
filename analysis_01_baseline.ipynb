# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/model/daily_features.csv")

df.head()
# Out:
#          date  dow  week  month  days_since_start  sleep_total_hours  \
# 0  2026-02-06    4     6      2                 0           6.083333
# 1  2026-02-07    5     6      2                 1           8.016667
# 2  2026-02-08    6     6      2                 2           7.613056
# 3  2026-02-09    0     7      2                 3           5.175278
# 4  2026-02-10    1     7      2                 4           7.800000
#
#    sleep_deep_hours  sleep_rem_hours  sleep_light_hours  sleep_awake_hours  \
# 0          1.050000         0.533333           4.500000           0.583333
# 1          2.016667         2.333333           3.666667           0.216667
# 2          1.550000         2.150000           3.916667           0.150000
# 3          0.966667         1.800000           2.416667           0.100000
# 4          1.900000         2.100000           3.800000           0.316667
#
#    ...  resting_hr_7d_slope  avg_overnight_hrv_7d_mean  \
# ...

# %%
import sys
print(sys.executable)
# Out:
# /workspaces/garmin_lab/.venv/bin/python
